# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentNFR/openclassrooms_p06/blob/main/vgg16_from_imagenet_conf_3_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %% [markdown]
# # Import des donneés

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
convert_labels = {0: 'afghan_hound', 1: 'maltese_dog', 2: 'pomeranian', 3: 'samoyed', 4: 'scottish_deerhound'}

# %%
# Save train
X_train = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_train.npy', allow_pickle=True)
y_train = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_train.npy', allow_pickle=True)
# Save validation
X_val = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_val.npy', allow_pickle=True)
y_val = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_val.npy', allow_pickle=True)
# Save test
X_test = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_test.npy', allow_pickle=True)
y_test = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_test.npy', allow_pickle=True)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1749, 224, 224, 3), (375, 224, 224, 3), (376, 224, 224, 3))

# %%
y_train.shape, y_val.shape, y_test.shape
# Out:
# ((1749, 5), (375, 5), (376, 5))

# %% [markdown]
# # Evaluation des modèles

# %%
from sklearn.metrics import multilabel_confusion_matrix, classification_report

def print_confusion_matrix(confusion_matrix, axes, class_label, class_names, fontsize=14):

    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names,
    )

    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d", cbar=False, ax=axes)
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    axes.set_ylabel('True label')
    axes.set_xlabel('Predicted label')
    axes.set_title("Confusion Matrix\n for the class\n" + class_label)

def get_confusion_matrix(y_test, y_pred):
    m = multilabel_confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(8,12), facecolor='white')
    fig, ax = plt.subplots(1, 5, figsize=(12, 4))
    for i, [axes, cfs_matrix] in enumerate(zip(ax.flatten(), m)):
        print_confusion_matrix(cfs_matrix, axes, convert_labels[i], ["0", "1"])

    fig.subplots_adjust(left=0.1,
                        bottom=0.1, 
                        right=0.9, 
                        top=0.9, 
                        wspace=0.4, 
                        hspace=0.4)
    return fig


def evaluate_model(model, X_test, y_test, convert_labels):
    ### Predict
    y_pred = np.zeros((X_test.shape[0], 5))
    for y in range(y_pred.shape[0]):
        y_pred[y, np.argmax(model.predict(np.expand_dims(X_test[y], axis=0)))] = 1
    ### Confusion Matrix
    get_confusion_matrix(y_test, y_pred).show()
    ### Scores
    print('\n\n')
    print(classification_report(y_test,y_pred))

# %% [markdown]
# # Import du modèle d'apprentissage

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

def import_model(conv_model_type, input_shape=(224, 224, 3), weights=None, train_state=True, custom_model=None, lr=1e-3):
    if custom_model is not None:
        include_top = False
    else:
        include_top = True
    if conv_model_type == 'vgg':
        conv_model = tf.keras.applications.VGG16(
        include_top=include_top,
        input_shape=input_shape,
        weights=weights,
        input_tensor=None,
        pooling=None,
        classes=5,
        classifier_activation="softmax",
        )
    else:
        conv_model = tf.keras.applications.RestNet50(
        include_top=include_top,
        weights=weights,
        input_shape=input_shape,
        input_tensor=None,
        pooling=None,
        classes=5,
        classifier_activation="softmax",
        )

    # Freeze the pretrained weights
    conv_model.trainable = train_state

    # Construction du model
    model = Sequential()
    model.add(conv_model)
    if custom_model is not None:
        model.add(custom_model)

    # Summary
    model.summary()
    conv_model.summary()
    if custom_model is not None:
        custom_model.summary()

    # Compile
    model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=lr), 
    loss= 'categorical_crossentropy',
    metrics= ['accuracy']
    )

    return model

# %%
## Custom model 1
configuration_1 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='relu'),
            Dropout(0.2),
            Dense(1024, activation='relu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_1')

## Custom model 2
configuration_2 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='relu'),
            Dropout(0.2),
            Dense(1024, activation='relu'),
            Dropout(0.2),
            Dense(128, activation='relu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_2')

## Custom model 3
configuration_3 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='selu'),
            Dropout(0.2),
            Dense(1024, activation='selu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_3')

## Custom model 4
configuration_4 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='selu'),
            Dropout(0.2),
            Dense(1024, activation='selu'),
            Dropout(0.2),
            Dense(128, activation='selu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_4')

# %% [markdown]
# # Amelioration

# %%
epochs = 50
batch_size = 32

# %% [markdown]
# ### Configuration 3

# %%
model = import_model(conv_model_type='vgg', input_shape=(224, 224, 3), weights=None, train_state=False, custom_model=configuration_3, lr=1e-3)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    verbose=1
    )

plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()

evaluate_model(model, X_test, y_test, convert_labels)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  custom_config_3 (Sequential  (None, 5)                106964997
#  )
#
# =================================================================
# Total params: 121,679,685
# Trainable params: 106,964,997
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "custom_config_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_7 (Dense)             (None, 4096)              102764544
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense_8 (Dense)             (None, 1024)              4195328
#
#  dropout_6 (Dropout)         (None, 1024)              0
#
#  dense_9 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 106,964,997
# Trainable params: 106,964,997
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 19s 162ms/step - loss: 1.2054 - accuracy: 0.5432 - val_loss: 0.7971 - val_accuracy: 0.6800
# Epoch 2/50
# 54/54 [==============================] - 7s 132ms/step - loss: 0.8101 - accuracy: 0.6953 - val_loss: 0.7490 - val_accuracy: 0.7360
# Epoch 3/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.7130 - accuracy: 0.7138 - val_loss: 0.6214 - val_accuracy: 0.7360
# Epoch 4/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.6874 - accuracy: 0.7346 - val_loss: 0.7290 - val_accuracy: 0.7013
# Epoch 5/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.6684 - accuracy: 0.7464 - val_loss: 0.7061 - val_accuracy: 0.7227
# Epoch 6/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.6063 - accuracy: 0.7536 - val_loss: 0.7323 - val_accuracy: 0.7040
# Epoch 7/50
# 54/54 [==============================] - 7s 134ms/step - loss: 0.6223 - accuracy: 0.7430 - val_loss: 0.7234 - val_accuracy: 0.7173
# Epoch 8/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.5637 - accuracy: 0.7761 - val_loss: 0.6387 - val_accuracy: 0.7227
# Epoch 9/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.5497 - accuracy: 0.7806 - val_loss: 0.6291 - val_accuracy: 0.7413
# Epoch 10/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.5165 - accuracy: 0.7963 - val_loss: 0.9013 - val_accuracy: 0.6880
# Epoch 11/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.5414 - accuracy: 0.7856 - val_loss: 0.7825 - val_accuracy: 0.7147
# Epoch 12/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.5629 - accuracy: 0.7772 - val_loss: 0.5826 - val_accuracy: 0.7467
# Epoch 13/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.4180 - accuracy: 0.8361 - val_loss: 0.6324 - val_accuracy: 0.7307
# Epoch 14/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.5597 - accuracy: 0.7845 - val_loss: 1.0982 - val_accuracy: 0.7040
# Epoch 15/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.4360 - accuracy: 0.8288 - val_loss: 0.8167 - val_accuracy: 0.7040
# Epoch 16/50
# 54/54 [==============================] - 7s 134ms/step - loss: 0.5035 - accuracy: 0.8143 - val_loss: 0.6228 - val_accuracy: 0.7600
# Epoch 17/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.4525 - accuracy: 0.8165 - val_loss: 0.6059 - val_accuracy: 0.7680
# Epoch 18/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.3619 - accuracy: 0.8569 - val_loss: 0.6651 - val_accuracy: 0.7680
# Epoch 19/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3892 - accuracy: 0.8502 - val_loss: 0.6208 - val_accuracy: 0.7760
# Epoch 20/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.4241 - accuracy: 0.8429 - val_loss: 0.6885 - val_accuracy: 0.7280
# Epoch 21/50
# 54/54 [==============================] - 7s 129ms/step - loss: 0.3533 - accuracy: 0.8535 - val_loss: 0.7831 - val_accuracy: 0.7333
# Epoch 22/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.4660 - accuracy: 0.8277 - val_loss: 0.6918 - val_accuracy: 0.7440
# Epoch 23/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3203 - accuracy: 0.8732 - val_loss: 0.6186 - val_accuracy: 0.7520
# Epoch 24/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.4049 - accuracy: 0.8440 - val_loss: 1.2457 - val_accuracy: 0.6960
# Epoch 25/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3962 - accuracy: 0.8569 - val_loss: 0.8697 - val_accuracy: 0.7200
# Epoch 26/50
# 54/54 [==============================] - 7s 133ms/step - loss: 0.3201 - accuracy: 0.8777 - val_loss: 0.6502 - val_accuracy: 0.7627
# Epoch 27/50
# 54/54 [==============================] - 7s 134ms/step - loss: 0.3947 - accuracy: 0.8563 - val_loss: 0.9051 - val_accuracy: 0.7493
# Epoch 28/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3792 - accuracy: 0.8603 - val_loss: 0.7739 - val_accuracy: 0.7280
# Epoch 29/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.3017 - accuracy: 0.8793 - val_loss: 0.6485 - val_accuracy: 0.7627
# Epoch 30/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2557 - accuracy: 0.9113 - val_loss: 0.8290 - val_accuracy: 0.7467
# Epoch 31/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.2432 - accuracy: 0.9074 - val_loss: 0.8299 - val_accuracy: 0.7573
# Epoch 32/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.2844 - accuracy: 0.9001 - val_loss: 0.7059 - val_accuracy: 0.7840
# Epoch 33/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2657 - accuracy: 0.9001 - val_loss: 0.8984 - val_accuracy: 0.7253
# Epoch 34/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.2093 - accuracy: 0.9214 - val_loss: 0.8014 - val_accuracy: 0.7600
# Epoch 35/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2037 - accuracy: 0.9248 - val_loss: 1.4844 - val_accuracy: 0.7200
# Epoch 36/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3375 - accuracy: 0.8827 - val_loss: 1.0197 - val_accuracy: 0.7520
# Epoch 37/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2589 - accuracy: 0.9035 - val_loss: 0.8231 - val_accuracy: 0.7600
# Epoch 38/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.1777 - accuracy: 0.9276 - val_loss: 0.8915 - val_accuracy: 0.7627
# Epoch 39/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.1491 - accuracy: 0.9467 - val_loss: 0.8784 - val_accuracy: 0.7653
# Epoch 40/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3885 - accuracy: 0.8749 - val_loss: 1.3504 - val_accuracy: 0.7307
# Epoch 41/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2447 - accuracy: 0.9040 - val_loss: 0.7995 - val_accuracy: 0.7547
# Epoch 42/50
# 54/54 [==============================] - 7s 134ms/step - loss: 0.1457 - accuracy: 0.9461 - val_loss: 0.8433 - val_accuracy: 0.7547
# Epoch 43/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.1111 - accuracy: 0.9602 - val_loss: 1.0820 - val_accuracy: 0.7280
# Epoch 44/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.3977 - accuracy: 0.8715 - val_loss: 1.3025 - val_accuracy: 0.7253
# Epoch 45/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.1664 - accuracy: 0.9360 - val_loss: 0.9406 - val_accuracy: 0.7653
# Epoch 46/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.1698 - accuracy: 0.9360 - val_loss: 1.0656 - val_accuracy: 0.7467
# Epoch 47/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.1275 - accuracy: 0.9557 - val_loss: 0.8379 - val_accuracy: 0.7867
# Epoch 48/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.4081 - accuracy: 0.8895 - val_loss: 1.2574 - val_accuracy: 0.7520
# Epoch 49/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2009 - accuracy: 0.9293 - val_loss: 0.9251 - val_accuracy: 0.7493
# Epoch 50/50
#  4/54 [=>............................] - ETA: 5s - loss: 0.0709 - accuracy: 0.9848WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2700 batches). You may need to use the repeat() function when building your dataset.
# 54/54 [==============================] - 2s 34ms/step - loss: 0.0709 - accuracy: 0.9848 - val_loss: 1.0377 - val_accuracy: 0.7653
#               precision    recall  f1-score   support
#
#            0       0.67      0.91      0.77        66
#            1       0.78      0.78      0.78        81
#            2       0.93      0.79      0.85        71
#            3       0.67      0.80      0.73        75
#            4       0.98      0.65      0.78        83
#
#    micro avg       0.78      0.78      0.78       376
#    macro avg       0.81      0.79      0.78       376
# weighted avg       0.81      0.78      0.78       376
#  samples avg       0.78      0.78      0.78       376

# %% [markdown]
# ### Configuration 4

# %%
model = import_model(conv_model_type='vgg', input_shape=(224, 224, 3), weights=None, train_state=False, custom_model=configuration_4, lr=1e-3)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    verbose=1
    )

plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()

evaluate_model(model, X_test, y_test, convert_labels)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  custom_config_4 (Sequential  (None, 5)                107091717
#  )
#
# =================================================================
# Total params: 121,806,405
# Trainable params: 107,091,717
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "custom_config_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  dense_10 (Dense)            (None, 4096)              102764544
#
#  dropout_7 (Dropout)         (None, 4096)              0
#
#  dense_11 (Dense)            (None, 1024)              4195328
#
#  dropout_8 (Dropout)         (None, 1024)              0
#
#  dense_12 (Dense)            (None, 128)               131200
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 107,091,717
# Trainable params: 107,091,717
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 8s 137ms/step - loss: 1.4947 - accuracy: 0.5022 - val_loss: 0.8249 - val_accuracy: 0.6667
# Epoch 2/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.8218 - accuracy: 0.6807 - val_loss: 0.7553 - val_accuracy: 0.7227
# Epoch 3/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.8027 - accuracy: 0.6975 - val_loss: 0.6758 - val_accuracy: 0.7147
# Epoch 4/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.7753 - accuracy: 0.7160 - val_loss: 0.6199 - val_accuracy: 0.7547
# Epoch 5/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.6734 - accuracy: 0.7402 - val_loss: 0.7971 - val_accuracy: 0.7013
# Epoch 6/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.6880 - accuracy: 0.7452 - val_loss: 0.6856 - val_accuracy: 0.7200
# Epoch 7/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.6658 - accuracy: 0.7486 - val_loss: 0.8152 - val_accuracy: 0.7440
# Epoch 8/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.6633 - accuracy: 0.7553 - val_loss: 0.7397 - val_accuracy: 0.7173
# Epoch 9/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.6120 - accuracy: 0.7688 - val_loss: 0.6578 - val_accuracy: 0.7413
# Epoch 10/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.5839 - accuracy: 0.7834 - val_loss: 0.6804 - val_accuracy: 0.7360
# Epoch 11/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.6371 - accuracy: 0.7637 - val_loss: 0.6874 - val_accuracy: 0.7253
# Epoch 12/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.6291 - accuracy: 0.7699 - val_loss: 1.0578 - val_accuracy: 0.6827
# Epoch 13/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.5425 - accuracy: 0.7924 - val_loss: 0.6427 - val_accuracy: 0.7493
# Epoch 14/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.5016 - accuracy: 0.8098 - val_loss: 0.9843 - val_accuracy: 0.7173
# Epoch 15/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.4726 - accuracy: 0.8199 - val_loss: 0.6133 - val_accuracy: 0.7813
# Epoch 16/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.6027 - accuracy: 0.7856 - val_loss: 0.8041 - val_accuracy: 0.7227
# Epoch 17/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3850 - accuracy: 0.8479 - val_loss: 0.8715 - val_accuracy: 0.7707
# Epoch 18/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.4308 - accuracy: 0.8451 - val_loss: 0.7131 - val_accuracy: 0.7760
# Epoch 19/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.5183 - accuracy: 0.8075 - val_loss: 1.0970 - val_accuracy: 0.6773
# Epoch 20/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.4016 - accuracy: 0.8384 - val_loss: 0.7016 - val_accuracy: 0.7653
# Epoch 21/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.4061 - accuracy: 0.8485 - val_loss: 0.9291 - val_accuracy: 0.7573
# Epoch 22/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.5098 - accuracy: 0.8204 - val_loss: 0.6863 - val_accuracy: 0.7787
# Epoch 23/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.3147 - accuracy: 0.8765 - val_loss: 0.6209 - val_accuracy: 0.7653
# Epoch 24/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3424 - accuracy: 0.8636 - val_loss: 0.8720 - val_accuracy: 0.7653
# Epoch 25/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.4158 - accuracy: 0.8507 - val_loss: 0.9401 - val_accuracy: 0.7467
# Epoch 26/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3136 - accuracy: 0.8799 - val_loss: 0.8204 - val_accuracy: 0.7680
# Epoch 27/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3345 - accuracy: 0.8698 - val_loss: 0.8819 - val_accuracy: 0.7360
# Epoch 28/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3503 - accuracy: 0.8726 - val_loss: 0.6754 - val_accuracy: 0.7680
# Epoch 29/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.3322 - accuracy: 0.8838 - val_loss: 0.7370 - val_accuracy: 0.7813
# Epoch 30/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2509 - accuracy: 0.9052 - val_loss: 0.8404 - val_accuracy: 0.7733
# Epoch 31/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2822 - accuracy: 0.8911 - val_loss: 0.7258 - val_accuracy: 0.7920
# Epoch 32/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.3498 - accuracy: 0.8692 - val_loss: 0.9223 - val_accuracy: 0.7680
# Epoch 33/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.2500 - accuracy: 0.9080 - val_loss: 0.8802 - val_accuracy: 0.7920
# Epoch 34/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3727 - accuracy: 0.8816 - val_loss: 0.8953 - val_accuracy: 0.7520
# Epoch 35/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2487 - accuracy: 0.9029 - val_loss: 0.7861 - val_accuracy: 0.7707
# Epoch 36/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.3468 - accuracy: 0.8833 - val_loss: 0.7596 - val_accuracy: 0.7707
# Epoch 37/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.2409 - accuracy: 0.9102 - val_loss: 0.8323 - val_accuracy: 0.7680
# Epoch 38/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.2424 - accuracy: 0.9102 - val_loss: 0.7848 - val_accuracy: 0.7413
# Epoch 39/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2972 - accuracy: 0.8889 - val_loss: 0.6974 - val_accuracy: 0.7600
# Epoch 40/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.3822 - accuracy: 0.8704 - val_loss: 0.7894 - val_accuracy: 0.7787
# Epoch 41/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.1915 - accuracy: 0.9299 - val_loss: 0.8364 - val_accuracy: 0.7787
# Epoch 42/50
# 54/54 [==============================] - 7s 127ms/step - loss: 0.2574 - accuracy: 0.9108 - val_loss: 0.8410 - val_accuracy: 0.7707
# Epoch 43/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2604 - accuracy: 0.9091 - val_loss: 1.0660 - val_accuracy: 0.7653
# Epoch 44/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2010 - accuracy: 0.9304 - val_loss: 0.8712 - val_accuracy: 0.7680
# Epoch 45/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2922 - accuracy: 0.8945 - val_loss: 1.0952 - val_accuracy: 0.7280
# Epoch 46/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2214 - accuracy: 0.9304 - val_loss: 0.8213 - val_accuracy: 0.7787
# Epoch 47/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.2616 - accuracy: 0.9074 - val_loss: 0.6973 - val_accuracy: 0.7627
# Epoch 48/50
# 54/54 [==============================] - 7s 128ms/step - loss: 0.1955 - accuracy: 0.9287 - val_loss: 0.7730 - val_accuracy: 0.7813
# Epoch 49/50
# 54/54 [==============================] - 7s 134ms/step - loss: 0.3061 - accuracy: 0.8934 - val_loss: 0.8451 - val_accuracy: 0.7333
# Epoch 50/50
#  4/54 [=>............................] - ETA: 5s - loss: 0.2157 - accuracy: 0.9167WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2700 batches). You may need to use the repeat() function when building your dataset.
# 54/54 [==============================] - 1s 25ms/step - loss: 0.2157 - accuracy: 0.9167 - val_loss: 0.6736 - val_accuracy: 0.7840
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.76        66
#            1       0.81      0.63      0.71        81
#            2       0.72      0.92      0.81        71
#            3       0.82      0.77      0.79        75
#            4       0.85      0.76      0.80        83
#
#    micro avg       0.78      0.78      0.78       376
#    macro avg       0.78      0.78      0.78       376
# weighted avg       0.79      0.78      0.77       376
#  samples avg       0.78      0.78      0.78       376
