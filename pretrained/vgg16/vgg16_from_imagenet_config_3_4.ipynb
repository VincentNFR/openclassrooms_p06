# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentNFR/openclassrooms_p06/blob/main/pretrained/vgg16/vgg16_from_imagenet_config_3_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %matplotlib inline

# %% [markdown]
# # Import des donneés

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Save train
X_train = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_train.npy', allow_pickle=True)
y_train = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_train.npy', allow_pickle=True)
# Save validation
X_val = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_val.npy', allow_pickle=True)
y_val = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_val.npy', allow_pickle=True)
# Save test
X_test = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_test.npy', allow_pickle=True)
y_test = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_test.npy', allow_pickle=True)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1749, 224, 224, 3), (375, 224, 224, 3), (376, 224, 224, 3))

# %%
y_train.shape, y_val.shape, y_test.shape
# Out:
# ((1749, 5), (375, 5), (376, 5))

# %% [markdown]
# # Evaluation des modèles

# %%
from sklearn.metrics import confusion_matrix, classification_report

with open('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/label_bin.pkl', 'rb') as f:
    lb = pickle.load(f)

display(lb.classes_)

def evaluate_model(model, X_test, y_test, lb):
    ### Predict
    y_pred = [lb.classes_[np.argmax(model.predict(np.expand_dims(_X_test, axis=0)))] for _X_test in X_test]

    #Get the confusion matrix
    cf_matrix = confusion_matrix(lb.inverse_transform(y_test), y_pred)

    plt.figure(figsize=(8,8))
    ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues', cbar=False)

    ax.set_title('Confusion Matrix\n');
    ax.set_xlabel('\nPredicted Breed')
    ax.set_ylabel('Expected Breed');

    ## Ticket labels - List must be in alphabetical order
    ax.xaxis.set_ticklabels(lb.classes_, rotation=90)
    ax.yaxis.set_ticklabels(lb.classes_, rotation=0)

    ## Display the visualization of the Confusion Matrix.
    plt.show()
    ### Scores
    print('\n\n')
    print(classification_report(y_test,lb.transform(y_pred)))
# Out:
# array(['afghan_hound', 'maltese_dog', 'pomeranian', 'samoyed',
#        'scottish_deerhound'], dtype='<U18')

# %% [markdown]
# # Import du modèle d'apprentissage

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

def import_model(conv_model_type, input_shape=(224, 224, 3), weights=None, train_state=True, custom_model=None, lr=1e-3):
    if custom_model is not None:
        include_top = False
    else:
        include_top = True
    if conv_model_type == 'vgg':
        conv_model = tf.keras.applications.VGG16(
        include_top=include_top,
        input_shape=input_shape,
        weights=weights,
        input_tensor=None,
        pooling=None,
        classes=5,
        classifier_activation="softmax",
        )
    else:
        conv_model = tf.keras.applications.RestNet50(
        include_top=include_top,
        weights=weights,
        input_shape=input_shape,
        input_tensor=None,
        pooling=None,
        classes=5,
        classifier_activation="softmax",
        )

    # Freeze the pretrained weights
    conv_model.trainable = train_state

    # Construction du model
    model = Sequential()
    model.add(conv_model)
    if custom_model is not None:
        model.add(custom_model)

    # Summary
    model.summary()
    conv_model.summary()
    if custom_model is not None:
        custom_model.summary()

    # Compile
    model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=lr), 
    loss= 'categorical_crossentropy',
    metrics= ['accuracy']
    )

    return model

# %%
## Custom model 1
configuration_1 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='relu'),
            Dropout(0.2),
            Dense(1024, activation='relu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_1')

## Custom model 2
configuration_2 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='relu'),
            Dropout(0.2),
            Dense(1024, activation='relu'),
            Dropout(0.2),
            Dense(128, activation='relu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_2')

## Custom model 3
configuration_3 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='selu'),
            Dropout(0.2),
            Dense(1024, activation='selu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_3')

## Custom model 4
configuration_4 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='selu'),
            Dropout(0.2),
            Dense(1024, activation='selu'),
            Dropout(0.2),
            Dense(128, activation='selu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_4')

# %% [markdown]
# # Amelioration

# %%
epochs = 50
batch_size = 32

# %% [markdown]
# ### Configuration 3

# %%
model = import_model(conv_model_type='vgg', input_shape=(224, 224, 3), weights=None, train_state=False, custom_model=configuration_3, lr=1e-3)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    verbose=1
    )

plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()

evaluate_model(model, X_test, y_test, lb)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  custom_config_3 (Sequential  (None, 5)                106964997
#  )
#
# =================================================================
# Total params: 121,679,685
# Trainable params: 106,964,997
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "custom_config_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_7 (Dense)             (None, 4096)              102764544
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense_8 (Dense)             (None, 1024)              4195328
#
#  dropout_6 (Dropout)         (None, 1024)              0
#
#  dense_9 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 106,964,997
# Trainable params: 106,964,997
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 29s 313ms/step - loss: 1.1770 - accuracy: 0.5342 - val_loss: 0.9260 - val_accuracy: 0.6720
# Epoch 2/50
# 54/54 [==============================] - 12s 222ms/step - loss: 0.8265 - accuracy: 0.6880 - val_loss: 0.8278 - val_accuracy: 0.6747
# Epoch 3/50
# 54/54 [==============================] - 12s 224ms/step - loss: 0.7352 - accuracy: 0.7121 - val_loss: 0.8795 - val_accuracy: 0.6533
# Epoch 4/50
# 54/54 [==============================] - 12s 225ms/step - loss: 0.6837 - accuracy: 0.7200 - val_loss: 0.6705 - val_accuracy: 0.7227
# Epoch 5/50
# 54/54 [==============================] - 12s 227ms/step - loss: 0.6362 - accuracy: 0.7492 - val_loss: 0.7451 - val_accuracy: 0.6933
# Epoch 6/50
# 54/54 [==============================] - 12s 230ms/step - loss: 0.6158 - accuracy: 0.7531 - val_loss: 0.6993 - val_accuracy: 0.7040
# Epoch 7/50
# 54/54 [==============================] - 12s 231ms/step - loss: 0.6146 - accuracy: 0.7531 - val_loss: 0.6328 - val_accuracy: 0.7013
# Epoch 8/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.5964 - accuracy: 0.7649 - val_loss: 0.6661 - val_accuracy: 0.7333
# Epoch 9/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.5721 - accuracy: 0.7800 - val_loss: 0.6777 - val_accuracy: 0.7200
# Epoch 10/50
# 54/54 [==============================] - 13s 237ms/step - loss: 0.5266 - accuracy: 0.8013 - val_loss: 0.6724 - val_accuracy: 0.7200
# Epoch 11/50
# 54/54 [==============================] - 13s 237ms/step - loss: 0.5375 - accuracy: 0.7811 - val_loss: 0.6094 - val_accuracy: 0.7413
# Epoch 12/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4687 - accuracy: 0.8064 - val_loss: 0.7229 - val_accuracy: 0.7067
# Epoch 13/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.5385 - accuracy: 0.7873 - val_loss: 0.7761 - val_accuracy: 0.7333
# Epoch 14/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.5066 - accuracy: 0.8002 - val_loss: 0.6506 - val_accuracy: 0.7413
# Epoch 15/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4693 - accuracy: 0.8143 - val_loss: 0.6434 - val_accuracy: 0.7520
# Epoch 16/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.4247 - accuracy: 0.8238 - val_loss: 0.6253 - val_accuracy: 0.7653
# Epoch 17/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4556 - accuracy: 0.8199 - val_loss: 1.1510 - val_accuracy: 0.6853
# Epoch 18/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4506 - accuracy: 0.8210 - val_loss: 0.6724 - val_accuracy: 0.7547
# Epoch 19/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4558 - accuracy: 0.8182 - val_loss: 0.9541 - val_accuracy: 0.6987
# Epoch 20/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4453 - accuracy: 0.8159 - val_loss: 0.6081 - val_accuracy: 0.7520
# Epoch 21/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3570 - accuracy: 0.8591 - val_loss: 0.6634 - val_accuracy: 0.7787
# Epoch 22/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4758 - accuracy: 0.8210 - val_loss: 1.0245 - val_accuracy: 0.7173
# Epoch 23/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.3543 - accuracy: 0.8648 - val_loss: 0.7739 - val_accuracy: 0.7680
# Epoch 24/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3079 - accuracy: 0.8793 - val_loss: 0.7918 - val_accuracy: 0.7653
# Epoch 25/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4079 - accuracy: 0.8457 - val_loss: 1.1150 - val_accuracy: 0.7227
# Epoch 26/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3524 - accuracy: 0.8648 - val_loss: 0.7689 - val_accuracy: 0.7493
# Epoch 27/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4390 - accuracy: 0.8345 - val_loss: 0.8881 - val_accuracy: 0.7173
# Epoch 28/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3625 - accuracy: 0.8496 - val_loss: 0.7657 - val_accuracy: 0.7307
# Epoch 29/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2717 - accuracy: 0.8996 - val_loss: 0.6611 - val_accuracy: 0.7680
# Epoch 30/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3311 - accuracy: 0.8698 - val_loss: 0.6974 - val_accuracy: 0.7520
# Epoch 31/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2843 - accuracy: 0.8911 - val_loss: 0.7528 - val_accuracy: 0.7467
# Epoch 32/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2943 - accuracy: 0.8923 - val_loss: 0.8395 - val_accuracy: 0.7227
# Epoch 33/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3111 - accuracy: 0.8793 - val_loss: 0.7720 - val_accuracy: 0.7573
# Epoch 34/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3227 - accuracy: 0.8799 - val_loss: 0.7965 - val_accuracy: 0.7413
# Epoch 35/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.2027 - accuracy: 0.9220 - val_loss: 0.6731 - val_accuracy: 0.7733
# Epoch 36/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.1712 - accuracy: 0.9383 - val_loss: 0.8890 - val_accuracy: 0.7547
# Epoch 37/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.1860 - accuracy: 0.9315 - val_loss: 0.8964 - val_accuracy: 0.7493
# Epoch 38/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3271 - accuracy: 0.8777 - val_loss: 0.7573 - val_accuracy: 0.7600
# Epoch 39/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2945 - accuracy: 0.8878 - val_loss: 0.8658 - val_accuracy: 0.7627
# Epoch 40/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.1854 - accuracy: 0.9355 - val_loss: 0.7772 - val_accuracy: 0.7600
# Epoch 41/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.1332 - accuracy: 0.9523 - val_loss: 0.8494 - val_accuracy: 0.7493
# Epoch 42/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.1964 - accuracy: 0.9276 - val_loss: 1.3423 - val_accuracy: 0.7280
# Epoch 43/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3689 - accuracy: 0.8788 - val_loss: 1.3225 - val_accuracy: 0.7093
# Epoch 44/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.1719 - accuracy: 0.9360 - val_loss: 0.8798 - val_accuracy: 0.7547
# Epoch 45/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2635 - accuracy: 0.9119 - val_loss: 1.4843 - val_accuracy: 0.7120
# Epoch 46/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2103 - accuracy: 0.9192 - val_loss: 0.9200 - val_accuracy: 0.7653
# Epoch 47/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2097 - accuracy: 0.9237 - val_loss: 0.7889 - val_accuracy: 0.7787
# Epoch 48/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.0825 - accuracy: 0.9731 - val_loss: 1.0535 - val_accuracy: 0.7547
# Epoch 49/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.1910 - accuracy: 0.9282 - val_loss: 1.7576 - val_accuracy: 0.7040
# Epoch 50/50
#  4/54 [=>............................] - ETA: 9s - loss: 0.6115 - accuracy: 0.8106 WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2700 batches). You may need to use the repeat() function when building your dataset.
# 54/54 [==============================] - 3s 53ms/step - loss: 0.6115 - accuracy: 0.8106 - val_loss: 1.2425 - val_accuracy: 0.7280
#               precision    recall  f1-score   support
#
#            0       0.90      0.67      0.77        66
#            1       0.50      0.89      0.64        81
#            2       0.91      0.82      0.86        71
#            3       0.84      0.71      0.77        75
#            4       0.93      0.64      0.76        83
#
#    micro avg       0.74      0.74      0.74       376
#    macro avg       0.82      0.74      0.76       376
# weighted avg       0.81      0.74      0.76       376
#  samples avg       0.74      0.74      0.74       376

# %% [markdown]
# ### Configuration 4

# %%
model = import_model(conv_model_type='vgg', input_shape=(224, 224, 3), weights=None, train_state=False, custom_model=configuration_4, lr=1e-3)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    verbose=1
    )

plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()

evaluate_model(model, X_test, y_test, lb)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  custom_config_4 (Sequential  (None, 5)                107091717
#  )
#
# =================================================================
# Total params: 121,806,405
# Trainable params: 107,091,717
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "custom_config_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  dense_10 (Dense)            (None, 4096)              102764544
#
#  dropout_7 (Dropout)         (None, 4096)              0
#
#  dense_11 (Dense)            (None, 1024)              4195328
#
#  dropout_8 (Dropout)         (None, 1024)              0
#
#  dense_12 (Dense)            (None, 128)               131200
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 107,091,717
# Trainable params: 107,091,717
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 14s 241ms/step - loss: 1.4935 - accuracy: 0.5017 - val_loss: 0.7863 - val_accuracy: 0.7173
# Epoch 2/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.8818 - accuracy: 0.6796 - val_loss: 0.7696 - val_accuracy: 0.6747
# Epoch 3/50
# 54/54 [==============================] - 13s 237ms/step - loss: 0.8262 - accuracy: 0.6919 - val_loss: 0.9200 - val_accuracy: 0.6613
# Epoch 4/50
# 54/54 [==============================] - 13s 237ms/step - loss: 0.7910 - accuracy: 0.7026 - val_loss: 0.8194 - val_accuracy: 0.7227
# Epoch 5/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.6919 - accuracy: 0.7374 - val_loss: 0.7806 - val_accuracy: 0.7467
# Epoch 6/50
# 54/54 [==============================] - 13s 234ms/step - loss: 0.7492 - accuracy: 0.7250 - val_loss: 0.6922 - val_accuracy: 0.7173
# Epoch 7/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.6847 - accuracy: 0.7458 - val_loss: 0.7072 - val_accuracy: 0.7520
# Epoch 8/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.6545 - accuracy: 0.7531 - val_loss: 0.7662 - val_accuracy: 0.7200
# Epoch 9/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.6639 - accuracy: 0.7492 - val_loss: 0.8587 - val_accuracy: 0.7200
# Epoch 10/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.6316 - accuracy: 0.7694 - val_loss: 0.6459 - val_accuracy: 0.7200
# Epoch 11/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.6253 - accuracy: 0.7879 - val_loss: 0.8053 - val_accuracy: 0.7440
# Epoch 12/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.6402 - accuracy: 0.7626 - val_loss: 0.6982 - val_accuracy: 0.7467
# Epoch 13/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.5412 - accuracy: 0.7935 - val_loss: 0.9208 - val_accuracy: 0.7120
# Epoch 14/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.5647 - accuracy: 0.7834 - val_loss: 0.6601 - val_accuracy: 0.7707
# Epoch 15/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.5801 - accuracy: 0.7918 - val_loss: 0.6990 - val_accuracy: 0.7440
# Epoch 16/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.5752 - accuracy: 0.7896 - val_loss: 0.8477 - val_accuracy: 0.7333
# Epoch 17/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4698 - accuracy: 0.8288 - val_loss: 0.9140 - val_accuracy: 0.7307
# Epoch 18/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.5399 - accuracy: 0.7957 - val_loss: 0.7837 - val_accuracy: 0.7120
# Epoch 19/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4223 - accuracy: 0.8300 - val_loss: 0.6973 - val_accuracy: 0.7280
# Epoch 20/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.5484 - accuracy: 0.8092 - val_loss: 0.6905 - val_accuracy: 0.7387
# Epoch 21/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4434 - accuracy: 0.8406 - val_loss: 1.1952 - val_accuracy: 0.6800
# Epoch 22/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.5185 - accuracy: 0.8092 - val_loss: 0.6830 - val_accuracy: 0.7600
# Epoch 23/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.4275 - accuracy: 0.8367 - val_loss: 0.7841 - val_accuracy: 0.7573
# Epoch 24/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3834 - accuracy: 0.8535 - val_loss: 0.8154 - val_accuracy: 0.7760
# Epoch 25/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.3942 - accuracy: 0.8575 - val_loss: 1.0987 - val_accuracy: 0.6853
# Epoch 26/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.5220 - accuracy: 0.8300 - val_loss: 1.5031 - val_accuracy: 0.6827
# Epoch 27/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3835 - accuracy: 0.8524 - val_loss: 0.7323 - val_accuracy: 0.7493
# Epoch 28/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3445 - accuracy: 0.8788 - val_loss: 1.0269 - val_accuracy: 0.7040
# Epoch 29/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3393 - accuracy: 0.8709 - val_loss: 0.7919 - val_accuracy: 0.7467
# Epoch 30/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3132 - accuracy: 0.8883 - val_loss: 1.0879 - val_accuracy: 0.7093
# Epoch 31/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4002 - accuracy: 0.8552 - val_loss: 0.7451 - val_accuracy: 0.7627
# Epoch 32/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2049 - accuracy: 0.9226 - val_loss: 1.0171 - val_accuracy: 0.7600
# Epoch 33/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.3119 - accuracy: 0.8827 - val_loss: 0.8476 - val_accuracy: 0.7760
# Epoch 34/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2605 - accuracy: 0.9012 - val_loss: 0.7964 - val_accuracy: 0.7573
# Epoch 35/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3052 - accuracy: 0.8911 - val_loss: 1.8036 - val_accuracy: 0.6747
# Epoch 36/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.3681 - accuracy: 0.8687 - val_loss: 1.2499 - val_accuracy: 0.7067
# Epoch 37/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2486 - accuracy: 0.8928 - val_loss: 0.8116 - val_accuracy: 0.7867
# Epoch 38/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.4115 - accuracy: 0.8676 - val_loss: 1.2930 - val_accuracy: 0.7200
# Epoch 39/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2706 - accuracy: 0.8979 - val_loss: 0.8292 - val_accuracy: 0.7387
# Epoch 40/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2752 - accuracy: 0.9040 - val_loss: 0.9542 - val_accuracy: 0.7547
# Epoch 41/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.1987 - accuracy: 0.9254 - val_loss: 1.1595 - val_accuracy: 0.7493
# Epoch 42/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.2408 - accuracy: 0.8996 - val_loss: 0.7753 - val_accuracy: 0.7840
# Epoch 43/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2729 - accuracy: 0.8967 - val_loss: 0.6772 - val_accuracy: 0.7707
# Epoch 44/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.1975 - accuracy: 0.9248 - val_loss: 0.9626 - val_accuracy: 0.7707
# Epoch 45/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.3175 - accuracy: 0.8889 - val_loss: 1.0524 - val_accuracy: 0.7093
# Epoch 46/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.2219 - accuracy: 0.9091 - val_loss: 0.8922 - val_accuracy: 0.7547
# Epoch 47/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.1981 - accuracy: 0.9327 - val_loss: 0.8651 - val_accuracy: 0.7280
# Epoch 48/50
# 54/54 [==============================] - 13s 235ms/step - loss: 0.1754 - accuracy: 0.9310 - val_loss: 1.2570 - val_accuracy: 0.7573
# Epoch 49/50
# 54/54 [==============================] - 13s 236ms/step - loss: 0.2597 - accuracy: 0.9063 - val_loss: 1.0167 - val_accuracy: 0.7653
# Epoch 50/50
#  4/54 [=>............................] - ETA: 10s - loss: 0.1344 - accuracy: 0.9318WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2700 batches). You may need to use the repeat() function when building your dataset.
# 54/54 [==============================] - 3s 46ms/step - loss: 0.1344 - accuracy: 0.9318 - val_loss: 1.0662 - val_accuracy: 0.7707
#               precision    recall  f1-score   support
#
#            0       0.88      0.67      0.76        66
#            1       0.65      0.83      0.73        81
#            2       0.68      0.86      0.76        71
#            3       0.80      0.68      0.73        75
#            4       0.88      0.73      0.80        83
#
#    micro avg       0.76      0.76      0.76       376
#    macro avg       0.78      0.75      0.76       376
# weighted avg       0.78      0.76      0.76       376
#  samples avg       0.76      0.76      0.76       376
