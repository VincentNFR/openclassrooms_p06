# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentNFR/openclassrooms_p06/blob/main/scratch/vgg16/vgg16_from_scratch_config_3_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %matplotlib inline

# %% [markdown]
# # Import des donneés

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Save train
X_train = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_train.npy', allow_pickle=True)
y_train = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_train.npy', allow_pickle=True)
# Save validation
X_val = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_val.npy', allow_pickle=True)
y_val = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_val.npy', allow_pickle=True)
# Save test<
X_test = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_test.npy', allow_pickle=True)
y_test = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_test.npy', allow_pickle=True)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1749, 224, 224, 3), (375, 224, 224, 3), (376, 224, 224, 3))

# %%
y_train.shape, y_val.shape, y_test.shape
# Out:
# ((1749, 5), (375, 5), (376, 5))

# %% [markdown]
# # Evaluation des modèles

# %%
from sklearn.metrics import confusion_matrix, classification_report

with open('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/label_bin.pkl', 'rb') as f:
    lb = pickle.load(f)

display(lb.classes_)

def evaluate_model(model, X_test, y_test, lb):
    ### Predict
    y_pred = [lb.classes_[np.argmax(model.predict(np.expand_dims(_X_test, axis=0)))] for _X_test in X_test]

    #Get the confusion matrix
    cf_matrix = confusion_matrix(lb.inverse_transform(y_test), y_pred)

    plt.figure(figsize=(8,8))
    ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues', cbar=False)

    ax.set_title('Confusion Matrix\n');
    ax.set_xlabel('\nPredicted Breed')
    ax.set_ylabel('Expected Breed');

    ## Ticket labels - List must be in alphabetical order
    ax.xaxis.set_ticklabels(lb.classes_, rotation=90)
    ax.yaxis.set_ticklabels(lb.classes_, rotation=0)

    ## Display the visualization of the Confusion Matrix.
    plt.show()
    ### Scores
    print('\n\n')
    print(classification_report(y_test,lb.transform(y_pred)))
# Out:
# array(['afghan_hound', 'maltese_dog', 'pomeranian', 'samoyed',
#        'scottish_deerhound'], dtype='<U18')

# %% [markdown]
# # Import du modèle d'apprentissage

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

def import_model(conv_model_type, input_shape=(224, 224, 3), weights=None, train_state=True, custom_model=None, lr=1e-3):
    if custom_model is not None:
        include_top = False
    else:
        include_top = True
    if conv_model_type == 'vgg':
        conv_model = tf.keras.applications.VGG16(
        include_top=include_top,
        input_shape=input_shape,
        weights=weights,
        input_tensor=None,
        pooling=None,
        classes=5,
        classifier_activation="softmax",
        )
    else:
        conv_model = tf.keras.applications.RestNet50(
        include_top=include_top,
        weights=weights,
        input_shape=input_shape,
        input_tensor=None,
        pooling=None,
        classes=5,
        classifier_activation="softmax",
        )

    # Freeze the pretrained weights
    conv_model.trainable = train_state

    # Construction du model
    model = Sequential()
    model.add(conv_model)
    if custom_model is not None:
        model.add(custom_model)

    # Summary
    model.summary()
    conv_model.summary()
    if custom_model is not None:
        custom_model.summary()

    # Compile
    model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=lr), 
    loss= 'categorical_crossentropy',
    metrics= ['accuracy']
    )

    return model

# %%
## Custom model 1
configuration_1 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='relu'),
            Dropout(0.2),
            Dense(1024, activation='relu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_1')

## Custom model 2
configuration_2 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='relu'),
            Dropout(0.2),
            Dense(1024, activation='relu'),
            Dropout(0.2),
            Dense(128, activation='relu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_2')

## Custom model 3
configuration_3 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='selu'),
            Dropout(0.2),
            Dense(1024, activation='selu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_3')

## Custom model 4
configuration_4 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='selu'),
            Dropout(0.2),
            Dense(1024, activation='selu'),
            Dropout(0.2),
            Dense(128, activation='selu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_4')

# %% [markdown]
# # Amelioration

# %%
epochs = 50
batch_size = 32

# %% [markdown]
# ### Configuration 3

# %%
model = import_model(conv_model_type='vgg', input_shape=(224, 224, 3), weights=None, train_state=True, custom_model=configuration_3, lr=1e-3)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    verbose=1
    )

plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()

evaluate_model(model, X_test, y_test, lb)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  custom_config_3 (Sequential  (None, 5)                106964997
#  )
#
# =================================================================
# Total params: 121,679,685
# Trainable params: 121,679,685
# Non-trainable params: 0
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# Model: "custom_config_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 25088)             0
#
#  dense_21 (Dense)            (None, 4096)              102764544
#
#  dropout_15 (Dropout)        (None, 4096)              0
#
#  dense_22 (Dense)            (None, 1024)              4195328
#
#  dropout_16 (Dropout)        (None, 1024)              0
#
#  dense_23 (Dense)            (None, 5)                 5125
#
# =================================================================
# Total params: 106,964,997
# Trainable params: 106,964,997
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 38s 545ms/step - loss: 2.7939 - accuracy: 0.2160 - val_loss: 1.6310 - val_accuracy: 0.2080
# Epoch 2/50
# 54/54 [==============================] - 30s 550ms/step - loss: 1.6192 - accuracy: 0.1880 - val_loss: 1.6118 - val_accuracy: 0.1947
# Epoch 3/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6162 - accuracy: 0.1970 - val_loss: 1.6210 - val_accuracy: 0.2080
# Epoch 4/50
# 54/54 [==============================] - 29s 529ms/step - loss: 1.6229 - accuracy: 0.1897 - val_loss: 1.6142 - val_accuracy: 0.2027
# Epoch 5/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6270 - accuracy: 0.1925 - val_loss: 1.6218 - val_accuracy: 0.1947
# Epoch 6/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6190 - accuracy: 0.1869 - val_loss: 1.6134 - val_accuracy: 0.2000
# Epoch 7/50
# 54/54 [==============================] - 29s 533ms/step - loss: 1.6211 - accuracy: 0.1869 - val_loss: 1.6130 - val_accuracy: 0.2027
# Epoch 8/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6174 - accuracy: 0.2026 - val_loss: 1.6119 - val_accuracy: 0.2080
# Epoch 9/50
# 54/54 [==============================] - 29s 536ms/step - loss: 1.6163 - accuracy: 0.1987 - val_loss: 1.6204 - val_accuracy: 0.2000
# Epoch 10/50
# 54/54 [==============================] - 29s 535ms/step - loss: 1.6191 - accuracy: 0.1919 - val_loss: 1.6106 - val_accuracy: 0.1947
# Epoch 11/50
# 54/54 [==============================] - 29s 533ms/step - loss: 1.6166 - accuracy: 0.1891 - val_loss: 1.6103 - val_accuracy: 0.2080
# Epoch 12/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6141 - accuracy: 0.1992 - val_loss: 1.6142 - val_accuracy: 0.2080
# Epoch 13/50
# 54/54 [==============================] - 29s 535ms/step - loss: 1.6155 - accuracy: 0.1930 - val_loss: 1.6145 - val_accuracy: 0.2080
# Epoch 14/50
# 54/54 [==============================] - 30s 548ms/step - loss: 1.6191 - accuracy: 0.1813 - val_loss: 1.6157 - val_accuracy: 0.1947
# Epoch 15/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6162 - accuracy: 0.1942 - val_loss: 1.6110 - val_accuracy: 0.2080
# Epoch 16/50
# 54/54 [==============================] - 29s 535ms/step - loss: 1.6145 - accuracy: 0.1958 - val_loss: 1.6133 - val_accuracy: 0.1947
# Epoch 17/50
# 54/54 [==============================] - 29s 535ms/step - loss: 1.6150 - accuracy: 0.2088 - val_loss: 1.6190 - val_accuracy: 0.2080
# Epoch 18/50
# 54/54 [==============================] - 29s 535ms/step - loss: 1.6157 - accuracy: 0.1964 - val_loss: 1.6151 - val_accuracy: 0.2027
# Epoch 19/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6196 - accuracy: 0.2009 - val_loss: 1.6147 - val_accuracy: 0.1947
# Epoch 20/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6153 - accuracy: 0.1942 - val_loss: 1.6123 - val_accuracy: 0.1947
# Epoch 21/50
# 54/54 [==============================] - 29s 533ms/step - loss: 1.6133 - accuracy: 0.2071 - val_loss: 1.6190 - val_accuracy: 0.2000
# Epoch 22/50
# 54/54 [==============================] - 29s 533ms/step - loss: 1.6154 - accuracy: 0.1914 - val_loss: 1.6114 - val_accuracy: 0.1947
# Epoch 23/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6148 - accuracy: 0.1773 - val_loss: 1.6097 - val_accuracy: 0.2027
# Epoch 24/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6142 - accuracy: 0.2015 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 25/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6130 - accuracy: 0.2020 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 26/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6138 - accuracy: 0.2059 - val_loss: 1.6114 - val_accuracy: 0.2080
# Epoch 27/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6148 - accuracy: 0.1919 - val_loss: 1.6116 - val_accuracy: 0.2027
# Epoch 28/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6148 - accuracy: 0.2003 - val_loss: 1.6127 - val_accuracy: 0.1947
# Epoch 29/50
# 54/54 [==============================] - 29s 535ms/step - loss: 1.6161 - accuracy: 0.1841 - val_loss: 1.6142 - val_accuracy: 0.1947
# Epoch 30/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6152 - accuracy: 0.2071 - val_loss: 1.6118 - val_accuracy: 0.2027
# Epoch 31/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6132 - accuracy: 0.1947 - val_loss: 1.6104 - val_accuracy: 0.1947
# Epoch 32/50
# 54/54 [==============================] - 29s 533ms/step - loss: 1.6124 - accuracy: 0.1919 - val_loss: 1.6105 - val_accuracy: 0.2027
# Epoch 33/50
# 54/54 [==============================] - 29s 533ms/step - loss: 1.6146 - accuracy: 0.1801 - val_loss: 1.6112 - val_accuracy: 0.2000
# Epoch 34/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6148 - accuracy: 0.2043 - val_loss: 1.6109 - val_accuracy: 0.1947
# Epoch 35/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6157 - accuracy: 0.1768 - val_loss: 1.6119 - val_accuracy: 0.1947
# Epoch 36/50
# 54/54 [==============================] - 29s 533ms/step - loss: 1.6128 - accuracy: 0.1998 - val_loss: 1.6153 - val_accuracy: 0.1947
# Epoch 37/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6174 - accuracy: 0.2003 - val_loss: 1.6122 - val_accuracy: 0.2080
# Epoch 38/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6124 - accuracy: 0.1958 - val_loss: 1.6163 - val_accuracy: 0.2080
# Epoch 39/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6142 - accuracy: 0.1947 - val_loss: 1.6105 - val_accuracy: 0.1947
# Epoch 40/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6137 - accuracy: 0.1992 - val_loss: 1.6179 - val_accuracy: 0.1947
# Epoch 41/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6141 - accuracy: 0.2082 - val_loss: 1.6122 - val_accuracy: 0.2027
# Epoch 42/50
# 54/54 [==============================] - 29s 535ms/step - loss: 1.6127 - accuracy: 0.2082 - val_loss: 1.6099 - val_accuracy: 0.2080
# Epoch 43/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6134 - accuracy: 0.1970 - val_loss: 1.6176 - val_accuracy: 0.1947
# Epoch 44/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6160 - accuracy: 0.1947 - val_loss: 1.6132 - val_accuracy: 0.2000
# Epoch 45/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6147 - accuracy: 0.1964 - val_loss: 1.6147 - val_accuracy: 0.1947
# Epoch 46/50
# 54/54 [==============================] - 30s 548ms/step - loss: 1.6156 - accuracy: 0.1925 - val_loss: 1.6105 - val_accuracy: 0.2080
# Epoch 47/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6150 - accuracy: 0.2015 - val_loss: 1.6124 - val_accuracy: 0.1947
# Epoch 48/50
# 54/54 [==============================] - 29s 534ms/step - loss: 1.6134 - accuracy: 0.2026 - val_loss: 1.6116 - val_accuracy: 0.2027
# Epoch 49/50
# 54/54 [==============================] - 29s 535ms/step - loss: 1.6129 - accuracy: 0.2110 - val_loss: 1.6133 - val_accuracy: 0.2027
# Epoch 50/50
#  4/54 [=>............................] - ETA: 24s - loss: 1.6137 - accuracy: 0.1818WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2700 batches). You may need to use the repeat() function when building your dataset.
# 54/54 [==============================] - 4s 64ms/step - loss: 1.6137 - accuracy: 0.1818 - val_loss: 1.6159 - val_accuracy: 0.2027
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        66
#            1       0.00      0.00      0.00        81
#            2       0.19      1.00      0.32        71
#            3       0.00      0.00      0.00        75
#            4       0.00      0.00      0.00        83
#
#    micro avg       0.19      0.19      0.19       376
#    macro avg       0.04      0.20      0.06       376
# weighted avg       0.04      0.19      0.06       376
#  samples avg       0.19      0.19      0.19       376
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Configuration 4

# %%
model = import_model(conv_model_type='vgg', input_shape=(224, 224, 3), weights=None, train_state=True, custom_model=configuration_4, lr=1e-3)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    verbose=1
    )

plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()

evaluate_model(model, X_test, y_test, lb)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  custom_config_4 (Sequential  (None, 5)                107091717
#  )
#
# =================================================================
# Total params: 121,806,405
# Trainable params: 121,806,405
# Non-trainable params: 0
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# Model: "custom_config_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 25088)             0
#
#  dense_24 (Dense)            (None, 4096)              102764544
#
#  dropout_17 (Dropout)        (None, 4096)              0
#
#  dense_25 (Dense)            (None, 1024)              4195328
#
#  dropout_18 (Dropout)        (None, 1024)              0
#
#  dense_26 (Dense)            (None, 128)               131200
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_27 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 107,091,717
# Trainable params: 107,091,717
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 32s 568ms/step - loss: 2.7586 - accuracy: 0.1992 - val_loss: 1.6126 - val_accuracy: 0.2080
# Epoch 2/50
# 54/54 [==============================] - 29s 546ms/step - loss: 1.6324 - accuracy: 0.2003 - val_loss: 1.6113 - val_accuracy: 0.2080
# Epoch 3/50
# 54/54 [==============================] - 29s 532ms/step - loss: 1.6265 - accuracy: 0.1886 - val_loss: 1.6257 - val_accuracy: 0.2080
# Epoch 4/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6273 - accuracy: 0.1908 - val_loss: 1.6293 - val_accuracy: 0.1947
# Epoch 5/50
# 54/54 [==============================] - 29s 540ms/step - loss: 1.6232 - accuracy: 0.2217 - val_loss: 1.6123 - val_accuracy: 0.2027
# Epoch 6/50
# 54/54 [==============================] - 29s 536ms/step - loss: 1.6252 - accuracy: 0.1874 - val_loss: 1.6365 - val_accuracy: 0.2000
# Epoch 7/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6294 - accuracy: 0.1998 - val_loss: 1.6158 - val_accuracy: 0.1947
# Epoch 8/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6242 - accuracy: 0.1925 - val_loss: 1.6112 - val_accuracy: 0.1947
# Epoch 9/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6285 - accuracy: 0.2003 - val_loss: 1.6158 - val_accuracy: 0.2000
# Epoch 10/50
# 54/54 [==============================] - 29s 539ms/step - loss: 1.6290 - accuracy: 0.1818 - val_loss: 1.6162 - val_accuracy: 0.2080
# Epoch 11/50
# 54/54 [==============================] - 29s 539ms/step - loss: 1.6263 - accuracy: 0.2043 - val_loss: 1.6199 - val_accuracy: 0.1947
# Epoch 12/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6252 - accuracy: 0.2020 - val_loss: 1.6201 - val_accuracy: 0.2080
# Epoch 13/50
# 54/54 [==============================] - 29s 539ms/step - loss: 1.6258 - accuracy: 0.1841 - val_loss: 1.6134 - val_accuracy: 0.1947
# Epoch 14/50
# 54/54 [==============================] - 29s 540ms/step - loss: 1.6246 - accuracy: 0.1998 - val_loss: 1.6116 - val_accuracy: 0.2080
# Epoch 15/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6246 - accuracy: 0.1902 - val_loss: 1.6156 - val_accuracy: 0.2027
# Epoch 16/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6310 - accuracy: 0.1846 - val_loss: 1.6160 - val_accuracy: 0.2080
# Epoch 17/50
# 54/54 [==============================] - 29s 536ms/step - loss: 1.6290 - accuracy: 0.1813 - val_loss: 1.6221 - val_accuracy: 0.2027
# Epoch 18/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6241 - accuracy: 0.2026 - val_loss: 1.6153 - val_accuracy: 0.2027
# Epoch 19/50
# 54/54 [==============================] - 29s 540ms/step - loss: 1.6233 - accuracy: 0.2160 - val_loss: 1.6179 - val_accuracy: 0.2080
# Epoch 20/50
# 54/54 [==============================] - 29s 539ms/step - loss: 1.6219 - accuracy: 0.1981 - val_loss: 1.6199 - val_accuracy: 0.1947
# Epoch 21/50
# 54/54 [==============================] - 29s 540ms/step - loss: 1.6236 - accuracy: 0.1998 - val_loss: 1.6158 - val_accuracy: 0.2027
# Epoch 22/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6255 - accuracy: 0.1835 - val_loss: 1.6188 - val_accuracy: 0.2027
# Epoch 23/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6202 - accuracy: 0.2093 - val_loss: 1.6173 - val_accuracy: 0.2000
# Epoch 24/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6306 - accuracy: 0.2003 - val_loss: 1.6144 - val_accuracy: 0.2080
# Epoch 25/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6235 - accuracy: 0.2043 - val_loss: 1.6115 - val_accuracy: 0.2000
# Epoch 26/50
# 54/54 [==============================] - 29s 536ms/step - loss: 1.6249 - accuracy: 0.1947 - val_loss: 1.6196 - val_accuracy: 0.2027
# Epoch 27/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6187 - accuracy: 0.1992 - val_loss: 1.6177 - val_accuracy: 0.1947
# Epoch 28/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6243 - accuracy: 0.1869 - val_loss: 1.6126 - val_accuracy: 0.2027
# Epoch 29/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6214 - accuracy: 0.1880 - val_loss: 1.6132 - val_accuracy: 0.2027
# Epoch 30/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6248 - accuracy: 0.1947 - val_loss: 1.6142 - val_accuracy: 0.2080
# Epoch 31/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6264 - accuracy: 0.1953 - val_loss: 1.6154 - val_accuracy: 0.2027
# Epoch 32/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6232 - accuracy: 0.1987 - val_loss: 1.6252 - val_accuracy: 0.1947
# Epoch 33/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6193 - accuracy: 0.1829 - val_loss: 1.6103 - val_accuracy: 0.2027
# Epoch 34/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6208 - accuracy: 0.1886 - val_loss: 1.6188 - val_accuracy: 0.1947
# Epoch 35/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6240 - accuracy: 0.1897 - val_loss: 1.6124 - val_accuracy: 0.2080
# Epoch 36/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6207 - accuracy: 0.1930 - val_loss: 1.6123 - val_accuracy: 0.2000
# Epoch 37/50
# 54/54 [==============================] - 29s 539ms/step - loss: 1.6241 - accuracy: 0.1835 - val_loss: 1.6131 - val_accuracy: 0.2080
# Epoch 38/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6171 - accuracy: 0.1942 - val_loss: 1.6213 - val_accuracy: 0.2000
# Epoch 39/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6199 - accuracy: 0.1874 - val_loss: 1.6113 - val_accuracy: 0.2000
# Epoch 40/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6191 - accuracy: 0.2059 - val_loss: 1.6155 - val_accuracy: 0.1947
# Epoch 41/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6213 - accuracy: 0.1779 - val_loss: 1.6223 - val_accuracy: 0.1947
# Epoch 42/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6219 - accuracy: 0.1981 - val_loss: 1.6129 - val_accuracy: 0.2000
# Epoch 43/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6171 - accuracy: 0.2015 - val_loss: 1.6106 - val_accuracy: 0.2027
# Epoch 44/50
# 54/54 [==============================] - 29s 535ms/step - loss: 1.6181 - accuracy: 0.2076 - val_loss: 1.6163 - val_accuracy: 0.1947
# Epoch 45/50
# 54/54 [==============================] - 29s 537ms/step - loss: 1.6235 - accuracy: 0.2059 - val_loss: 1.6283 - val_accuracy: 0.1947
# Epoch 46/50
# 54/54 [==============================] - 29s 539ms/step - loss: 1.6202 - accuracy: 0.2031 - val_loss: 1.6235 - val_accuracy: 0.1947
# Epoch 47/50
# 54/54 [==============================] - 29s 541ms/step - loss: 1.6197 - accuracy: 0.1998 - val_loss: 1.6242 - val_accuracy: 0.2080
# Epoch 48/50
# 54/54 [==============================] - 29s 538ms/step - loss: 1.6209 - accuracy: 0.2048 - val_loss: 1.6111 - val_accuracy: 0.2080
# Epoch 49/50
# 54/54 [==============================] - 29s 539ms/step - loss: 1.6206 - accuracy: 0.2071 - val_loss: 1.6114 - val_accuracy: 0.1947
# Epoch 50/50
#  4/54 [=>............................] - ETA: 24s - loss: 1.6089 - accuracy: 0.2576WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2700 batches). You may need to use the repeat() function when building your dataset.
# 54/54 [==============================] - 4s 63ms/step - loss: 1.6089 - accuracy: 0.2576 - val_loss: 1.6224 - val_accuracy: 0.1947
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        66
#            1       0.00      0.00      0.00        81
#            2       0.00      0.00      0.00        71
#            3       0.20      1.00      0.33        75
#            4       0.00      0.00      0.00        83
#
#    micro avg       0.20      0.20      0.20       376
#    macro avg       0.04      0.20      0.07       376
# weighted avg       0.04      0.20      0.07       376
#  samples avg       0.20      0.20      0.20       376
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
