# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentNFR/openclassrooms_p06/blob/main/vgg16_from_scratch_suite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %% [markdown]
# # Import des donneés

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
convert_labels = {0: 'afghan_hound', 1: 'maltese_dog', 2: 'pomeranian', 3: 'samoyed', 4: 'scottish_deerhound'}

# %%
# Save train
X_train = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_train.npy', allow_pickle=True)
y_train = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_train.npy', allow_pickle=True)
# Save validation
X_val = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_val.npy', allow_pickle=True)
y_val = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_val.npy', allow_pickle=True)
# Save test
X_test = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/X_test.npy', allow_pickle=True)
y_test = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/y_test.npy', allow_pickle=True)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1749, 224, 224, 3), (375, 224, 224, 3), (376, 224, 224, 3))

# %%
y_train.shape, y_val.shape, y_test.shape
# Out:
# ((1749, 5), (375, 5), (376, 5))

# %% [markdown]
# # Evaluation des modèles

# %%
from sklearn.metrics import multilabel_confusion_matrix, classification_report

def print_confusion_matrix(confusion_matrix, axes, class_label, class_names, fontsize=14):

    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names,
    )

    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d", cbar=False, ax=axes)
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    axes.set_ylabel('True label')
    axes.set_xlabel('Predicted label')
    axes.set_title("Confusion Matrix\n for the class\n" + class_label)

def get_confusion_matrix(y_test, y_pred):
    m = multilabel_confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(8,12), facecolor='white')
    fig, ax = plt.subplots(1, 5, figsize=(12, 4))
    for i, [axes, cfs_matrix] in enumerate(zip(ax.flatten(), m)):
        print_confusion_matrix(cfs_matrix, axes, convert_labels[i], ["0", "1"])

    fig.subplots_adjust(left=0.1,
                        bottom=0.1, 
                        right=0.9, 
                        top=0.9, 
                        wspace=0.4, 
                        hspace=0.4)
    return fig


def evaluate_model(model, X_test, y_test, convert_labels):
    ### Predict
    y_pred = np.zeros((X_test.shape[0], 5))
    for y in range(y_pred.shape[0]):
        y_pred[y, np.argmax(model.predict(np.expand_dims(X_test[y], axis=0)))] = 1
    ### Confusion Matrix
    get_confusion_matrix(y_test, y_pred).show()
    ### Scores
    print('\n\n')
    print(classification_report(y_test,y_pred))

# %% [markdown]
# # Import du modèle d'apprentissage

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

def import_model(conv_model_type, input_shape=(224, 224, 3), weights=None, train_state=True, custom_model=None, lr=1e-3):
    if custom_model is not None:
        include_top = False
    else:
        include_top = True
    if conv_model_type == 'vgg':
        conv_model = tf.keras.applications.VGG16(
        include_top=include_top,
        input_shape=input_shape,
        weights=weights,
        input_tensor=None,
        pooling=None,
        classes=5,
        classifier_activation="softmax",
        )
    else:
        conv_model = tf.keras.applications.RestNet50(
        include_top=include_top,
        weights=weights,
        input_shape=input_shape,
        input_tensor=None,
        pooling=None,
        classes=5,
        classifier_activation="softmax",
        )

    # Freeze the pretrained weights
    conv_model.trainable = train_state

    # Construction du model
    model = Sequential()
    model.add(conv_model)
    if custom_model is not None:
        model.add(custom_model)

    # Summary
    model.summary()
    conv_model.summary()
    if custom_model is not None:
        custom_model.summary()

    # Compile
    model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=lr), 
    loss= 'categorical_crossentropy',
    metrics= ['accuracy']
    )

    return model

# %%
## Custom model 1
configuration_1 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='relu'),
            Dropout(0.2),
            Dense(1024, activation='relu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_1')

## Custom model 2
configuration_2 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='relu'),
            Dropout(0.2),
            Dense(1024, activation='relu'),
            Dropout(0.2),
            Dense(128, activation='relu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_2')

## Custom model 3
configuration_3 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='selu'),
            Dropout(0.2),
            Dense(1024, activation='selu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_3')

## Custom model 4
configuration_4 = Sequential(
    layers=[
            Flatten(),
            Dense(4096, activation='selu'),
            Dropout(0.2),
            Dense(1024, activation='selu'),
            Dropout(0.2),
            Dense(128, activation='selu'),
            Dropout(0.2),
            Dense(5, activation='softmax')
    ],
    name = 'custom_config_4')

# %% [markdown]
# # Amelioration

# %%
epochs = 50
batch_size = 32

# %% [markdown]
# ### Configuration 3

# %%
model = import_model(conv_model_type='vgg', input_shape=(224, 224, 3), weights=None, train_state=True, custom_model=configuration_3, lr=1e-3)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    verbose=1
    )

plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()

evaluate_model(model, X_test, y_test, convert_labels)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  custom_config_3 (Sequential  (None, 5)                106964997
#  )
#
# =================================================================
# Total params: 121,679,685
# Trainable params: 121,679,685
# Non-trainable params: 0
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# Model: "custom_config_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 25088)             0
#
#  dense_21 (Dense)            (None, 4096)              102764544
#
#  dropout_15 (Dropout)        (None, 4096)              0
#
#  dense_22 (Dense)            (None, 1024)              4195328
#
#  dropout_16 (Dropout)        (None, 1024)              0
#
#  dense_23 (Dense)            (None, 5)                 5125
#
# =================================================================
# Total params: 106,964,997
# Trainable params: 106,964,997
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 80s 1s/step - loss: 1.9827 - accuracy: 0.1857 - val_loss: 1.6133 - val_accuracy: 0.2080
# Epoch 2/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6342 - accuracy: 0.2037 - val_loss: 1.6159 - val_accuracy: 0.1947
# Epoch 3/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6254 - accuracy: 0.1790 - val_loss: 1.6200 - val_accuracy: 0.2000
# Epoch 4/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6260 - accuracy: 0.1947 - val_loss: 1.6185 - val_accuracy: 0.2080
# Epoch 5/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6189 - accuracy: 0.1964 - val_loss: 1.6149 - val_accuracy: 0.2027
# Epoch 6/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6297 - accuracy: 0.1936 - val_loss: 1.6267 - val_accuracy: 0.2027
# Epoch 7/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6210 - accuracy: 0.1886 - val_loss: 1.6128 - val_accuracy: 0.2080
# Epoch 8/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6149 - accuracy: 0.2076 - val_loss: 1.6438 - val_accuracy: 0.2027
# Epoch 9/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6213 - accuracy: 0.2003 - val_loss: 1.6117 - val_accuracy: 0.2000
# Epoch 10/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6176 - accuracy: 0.1958 - val_loss: 1.6107 - val_accuracy: 0.1947
# Epoch 11/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6177 - accuracy: 0.1880 - val_loss: 1.6144 - val_accuracy: 0.2080
# Epoch 12/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6198 - accuracy: 0.2031 - val_loss: 1.6141 - val_accuracy: 0.1947
# Epoch 13/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6171 - accuracy: 0.1813 - val_loss: 1.6173 - val_accuracy: 0.2000
# Epoch 14/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6177 - accuracy: 0.1908 - val_loss: 1.6131 - val_accuracy: 0.2080
# Epoch 15/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6163 - accuracy: 0.1936 - val_loss: 1.6096 - val_accuracy: 0.2080
# Epoch 16/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6157 - accuracy: 0.1953 - val_loss: 1.6097 - val_accuracy: 0.1947
# Epoch 17/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6144 - accuracy: 0.1930 - val_loss: 1.6103 - val_accuracy: 0.2080
# Epoch 18/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6129 - accuracy: 0.2088 - val_loss: 1.6114 - val_accuracy: 0.2027
# Epoch 19/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6137 - accuracy: 0.1953 - val_loss: 1.6132 - val_accuracy: 0.1947
# Epoch 20/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6150 - accuracy: 0.2037 - val_loss: 1.6105 - val_accuracy: 0.2080
# Epoch 21/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6172 - accuracy: 0.2037 - val_loss: 1.6104 - val_accuracy: 0.2027
# Epoch 22/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6131 - accuracy: 0.1936 - val_loss: 1.6167 - val_accuracy: 0.2080
# Epoch 23/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6168 - accuracy: 0.1829 - val_loss: 1.6095 - val_accuracy: 0.2000
# Epoch 24/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6144 - accuracy: 0.1880 - val_loss: 1.6105 - val_accuracy: 0.1947
# Epoch 25/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6136 - accuracy: 0.1947 - val_loss: 1.6112 - val_accuracy: 0.2000
# Epoch 26/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6136 - accuracy: 0.1992 - val_loss: 1.6115 - val_accuracy: 0.2027
# Epoch 27/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6144 - accuracy: 0.2099 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 28/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6119 - accuracy: 0.2043 - val_loss: 1.6108 - val_accuracy: 0.1947
# Epoch 29/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6139 - accuracy: 0.2116 - val_loss: 1.6110 - val_accuracy: 0.1947
# Epoch 30/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6144 - accuracy: 0.1919 - val_loss: 1.6138 - val_accuracy: 0.2080
# Epoch 31/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6150 - accuracy: 0.1936 - val_loss: 1.6102 - val_accuracy: 0.2080
# Epoch 32/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6149 - accuracy: 0.1897 - val_loss: 1.6131 - val_accuracy: 0.2027
# Epoch 33/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6161 - accuracy: 0.1925 - val_loss: 1.6201 - val_accuracy: 0.2000
# Epoch 34/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6197 - accuracy: 0.1930 - val_loss: 1.6142 - val_accuracy: 0.1947
# Epoch 35/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6142 - accuracy: 0.2155 - val_loss: 1.6121 - val_accuracy: 0.2080
# Epoch 36/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6156 - accuracy: 0.1925 - val_loss: 1.6156 - val_accuracy: 0.1947
# Epoch 37/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6149 - accuracy: 0.1953 - val_loss: 1.6100 - val_accuracy: 0.2080
# Epoch 38/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6134 - accuracy: 0.1970 - val_loss: 1.6130 - val_accuracy: 0.2027
# Epoch 39/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6156 - accuracy: 0.1992 - val_loss: 1.6100 - val_accuracy: 0.2080
# Epoch 40/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6133 - accuracy: 0.1964 - val_loss: 1.6120 - val_accuracy: 0.2027
# Epoch 41/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6163 - accuracy: 0.1852 - val_loss: 1.6098 - val_accuracy: 0.2027
# Epoch 42/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6142 - accuracy: 0.1947 - val_loss: 1.6114 - val_accuracy: 0.2080
# Epoch 43/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6133 - accuracy: 0.2121 - val_loss: 1.6106 - val_accuracy: 0.2000
# Epoch 44/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6151 - accuracy: 0.1874 - val_loss: 1.6124 - val_accuracy: 0.2027
# Epoch 45/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6135 - accuracy: 0.1970 - val_loss: 1.6119 - val_accuracy: 0.1947
# Epoch 46/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6130 - accuracy: 0.1869 - val_loss: 1.6137 - val_accuracy: 0.2080
# Epoch 47/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6141 - accuracy: 0.2065 - val_loss: 1.6131 - val_accuracy: 0.1947
# Epoch 48/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6128 - accuracy: 0.2020 - val_loss: 1.6131 - val_accuracy: 0.2027
# Epoch 49/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6131 - accuracy: 0.1975 - val_loss: 1.6112 - val_accuracy: 0.2000
# Epoch 50/50
#  4/54 [=>............................] - ETA: 47s - loss: 1.6193 - accuracy: 0.1591WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2700 batches). You may need to use the repeat() function when building your dataset.
# 54/54 [==============================] - 7s 116ms/step - loss: 1.6193 - accuracy: 0.1591 - val_loss: 1.6110 - val_accuracy: 0.2000
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        66
#            1       0.00      0.00      0.00        81
#            2       0.00      0.00      0.00        71
#            3       0.00      0.00      0.00        75
#            4       0.22      1.00      0.36        83
#
#    micro avg       0.22      0.22      0.22       376
#    macro avg       0.04      0.20      0.07       376
# weighted avg       0.05      0.22      0.08       376
#  samples avg       0.22      0.22      0.22       376
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Configuration 4

# %%
model = import_model(conv_model_type='vgg', input_shape=(224, 224, 3), weights=None, train_state=True, custom_model=configuration_4, lr=1e-3)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    verbose=1
    )

plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()

evaluate_model(model, X_test, y_test, convert_labels)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  custom_config_4 (Sequential  (None, 5)                107091717
#  )
#
# =================================================================
# Total params: 121,806,405
# Trainable params: 121,806,405
# Non-trainable params: 0
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# Model: "custom_config_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 25088)             0
#
#  dense_24 (Dense)            (None, 4096)              102764544
#
#  dropout_17 (Dropout)        (None, 4096)              0
#
#  dense_25 (Dense)            (None, 1024)              4195328
#
#  dropout_18 (Dropout)        (None, 1024)              0
#
#  dense_26 (Dense)            (None, 128)               131200
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_27 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 107,091,717
# Trainable params: 107,091,717
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 58s 1s/step - loss: 2.1286 - accuracy: 0.1869 - val_loss: 1.6220 - val_accuracy: 0.2000
# Epoch 2/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6349 - accuracy: 0.2104 - val_loss: 1.6240 - val_accuracy: 0.1947
# Epoch 3/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6354 - accuracy: 0.2003 - val_loss: 1.6507 - val_accuracy: 0.2027
# Epoch 4/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6290 - accuracy: 0.2082 - val_loss: 1.6765 - val_accuracy: 0.1947
# Epoch 5/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6346 - accuracy: 0.2015 - val_loss: 1.6181 - val_accuracy: 0.2027
# Epoch 6/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6315 - accuracy: 0.1958 - val_loss: 1.6201 - val_accuracy: 0.2080
# Epoch 7/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6290 - accuracy: 0.1958 - val_loss: 1.6268 - val_accuracy: 0.1947
# Epoch 8/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6226 - accuracy: 0.2127 - val_loss: 1.6158 - val_accuracy: 0.2027
# Epoch 9/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6243 - accuracy: 0.1919 - val_loss: 1.6139 - val_accuracy: 0.2080
# Epoch 10/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6217 - accuracy: 0.1869 - val_loss: 1.6275 - val_accuracy: 0.2080
# Epoch 11/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6259 - accuracy: 0.1891 - val_loss: 1.6209 - val_accuracy: 0.1947
# Epoch 12/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6228 - accuracy: 0.2065 - val_loss: 1.6128 - val_accuracy: 0.1947
# Epoch 13/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6228 - accuracy: 0.1846 - val_loss: 1.6193 - val_accuracy: 0.1947
# Epoch 14/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6228 - accuracy: 0.1773 - val_loss: 1.6158 - val_accuracy: 0.2000
# Epoch 15/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6194 - accuracy: 0.1970 - val_loss: 1.6257 - val_accuracy: 0.2000
# Epoch 16/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6227 - accuracy: 0.1919 - val_loss: 1.6197 - val_accuracy: 0.2080
# Epoch 17/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6238 - accuracy: 0.2059 - val_loss: 1.6180 - val_accuracy: 0.1947
# Epoch 18/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6309 - accuracy: 0.1930 - val_loss: 1.6245 - val_accuracy: 0.2080
# Epoch 19/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6212 - accuracy: 0.2104 - val_loss: 1.6148 - val_accuracy: 0.2027
# Epoch 20/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6240 - accuracy: 0.1914 - val_loss: 1.6275 - val_accuracy: 0.2080
# Epoch 21/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6262 - accuracy: 0.1975 - val_loss: 1.6205 - val_accuracy: 0.2000
# Epoch 22/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6262 - accuracy: 0.1975 - val_loss: 1.6119 - val_accuracy: 0.2027
# Epoch 23/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6236 - accuracy: 0.2009 - val_loss: 1.6201 - val_accuracy: 0.1947
# Epoch 24/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6182 - accuracy: 0.2026 - val_loss: 1.6269 - val_accuracy: 0.2080
# Epoch 25/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6271 - accuracy: 0.1919 - val_loss: 1.6098 - val_accuracy: 0.1947
# Epoch 26/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6173 - accuracy: 0.2110 - val_loss: 1.6141 - val_accuracy: 0.2027
# Epoch 27/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6252 - accuracy: 0.1841 - val_loss: 1.6161 - val_accuracy: 0.2000
# Epoch 28/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6206 - accuracy: 0.1829 - val_loss: 1.6117 - val_accuracy: 0.1947
# Epoch 29/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6222 - accuracy: 0.1869 - val_loss: 1.6107 - val_accuracy: 0.2080
# Epoch 30/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6198 - accuracy: 0.2054 - val_loss: 1.6207 - val_accuracy: 0.1947
# Epoch 31/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6228 - accuracy: 0.1925 - val_loss: 1.6121 - val_accuracy: 0.2027
# Epoch 32/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6184 - accuracy: 0.1964 - val_loss: 1.6245 - val_accuracy: 0.2080
# Epoch 33/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6187 - accuracy: 0.1919 - val_loss: 1.6133 - val_accuracy: 0.2027
# Epoch 34/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6228 - accuracy: 0.1958 - val_loss: 1.6297 - val_accuracy: 0.2000
# Epoch 35/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6217 - accuracy: 0.1953 - val_loss: 1.6139 - val_accuracy: 0.2080
# Epoch 36/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6201 - accuracy: 0.1987 - val_loss: 1.6150 - val_accuracy: 0.2027
# Epoch 37/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6194 - accuracy: 0.1930 - val_loss: 1.6207 - val_accuracy: 0.2000
# Epoch 38/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6209 - accuracy: 0.1970 - val_loss: 1.6181 - val_accuracy: 0.1947
# Epoch 39/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6214 - accuracy: 0.2048 - val_loss: 1.6223 - val_accuracy: 0.2027
# Epoch 40/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6214 - accuracy: 0.1829 - val_loss: 1.6127 - val_accuracy: 0.2027
# Epoch 41/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6180 - accuracy: 0.2031 - val_loss: 1.6092 - val_accuracy: 0.2080
# Epoch 42/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6213 - accuracy: 0.1835 - val_loss: 1.6096 - val_accuracy: 0.2080
# Epoch 43/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6186 - accuracy: 0.1852 - val_loss: 1.6142 - val_accuracy: 0.2080
# Epoch 44/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6179 - accuracy: 0.1925 - val_loss: 1.6135 - val_accuracy: 0.2000
# Epoch 45/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6180 - accuracy: 0.1902 - val_loss: 1.6109 - val_accuracy: 0.2080
# Epoch 46/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6232 - accuracy: 0.1925 - val_loss: 1.6106 - val_accuracy: 0.1947
# Epoch 47/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6209 - accuracy: 0.1998 - val_loss: 1.6123 - val_accuracy: 0.1947
# Epoch 48/50
# 54/54 [==============================] - 56s 1s/step - loss: 1.6185 - accuracy: 0.1734 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 49/50
# 54/54 [==============================] - 55s 1s/step - loss: 1.6200 - accuracy: 0.1930 - val_loss: 1.6176 - val_accuracy: 0.1947
# Epoch 50/50
#  4/54 [=>............................] - ETA: 49s - loss: 1.6229 - accuracy: 0.1818WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2700 batches). You may need to use the repeat() function when building your dataset.
# 54/54 [==============================] - 7s 116ms/step - loss: 1.6229 - accuracy: 0.1818 - val_loss: 1.6157 - val_accuracy: 0.1947
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        66
#            1       0.22      1.00      0.35        81
#            2       0.00      0.00      0.00        71
#            3       0.00      0.00      0.00        75
#            4       0.00      0.00      0.00        83
#
#    micro avg       0.22      0.22      0.22       376
#    macro avg       0.04      0.20      0.07       376
# weighted avg       0.05      0.22      0.08       376
#  samples avg       0.22      0.22      0.22       376
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
