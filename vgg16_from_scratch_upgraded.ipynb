# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentNFR/openclassrooms_p06/blob/main/vgg16_from_scratch_upgraded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Import des donneés

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
raw_image_tensor = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/images_reduced.npy', allow_pickle=True)
raw_label_tensor = np.load('/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/data/label_reduced.npy', allow_pickle=True)

# %%
raw_image_tensor.shape, raw_label_tensor.shape
# Out:
# ((1124,), (1124,))

# %% [markdown]
# # Preparation des sets

# %%
from numpy import expand_dims
import tensorflow as tf
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from skimage.transform import resize
from tqdm.notebook import trange, tqdm

np.random.seed(1)

image_generator = ImageDataGenerator(
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    rotation_range = 20,
    width_shift_range = 0.2,
    height_shift_range = 0.2
    )

def generate_new_image(image, target_size=(224,224), seed=1):
    it = image_generator.flow(expand_dims(image, 0), batch_size=1, seed=seed).next()[0].astype('uint8')
    new_image = resize(it, target_size, anti_aliasing=True)
    return new_image

def normalize(x):
    return x/255.

def generate_dataframe(raw_label_tensor, raw_image_tensor, nb_images_per_class=100, target_size=(224,224)):
    """
    Genere une image à partir du jeu de données
    - Image aléatoire
    - Image resize
    - Image normalisee
    return df['Images','Labels'], Dict(Label: Breed)
    """
    label_unique = np.unique(raw_label_tensor)
    df = pd.DataFrame(columns=['Images', 'Labels'])
    convert_labels = dict()
    for i in trange(len(label_unique), desc='Total set'):
        breed = label_unique[i]
        convert_labels[i] = breed
        n_image_to_create = nb_images_per_class
        samples = np.where(raw_label_tensor==breed)[0]
        label_arr = np.zeros((len(label_unique)))
        label_arr[i] = 1
        for j in tqdm(range(n_image_to_create), desc=breed):
            sample_image = raw_image_tensor[np.random.choice(samples)]
            new_image = generate_new_image(sample_image)
            
            df = df.append(dict(zip(df.columns,[new_image, label_arr])), ignore_index=True)
    df['Images'].apply(normalize)
    return df, convert_labels

# %%
d, convert_labels = generate_dataframe(raw_label_tensor, raw_image_tensor, nb_images_per_class=500, target_size=(224,224))
# Out:
# Total set:   0%|          | 0/5 [00:00<?, ?it/s]
# afghan_hound:   0%|          | 0/500 [00:00<?, ?it/s]
# maltese_dog:   0%|          | 0/500 [00:00<?, ?it/s]
# pomeranian:   0%|          | 0/500 [00:00<?, ?it/s]
# samoyed:   0%|          | 0/500 [00:00<?, ?it/s]
# scottish_deerhound:   0%|          | 0/500 [00:00<?, ?it/s]

# %%
from sklearn.model_selection import train_test_split

def split_dataframe(df, x_cols, y_cols, train_split=0.7, test_split=0.5, random_state=0):
    """
    Split du dataset en 3 parties avec mélange :
        - Train set
        - Validation set
        - Test set
    """
    X_train, X_tmp, y_train, y_tmp = train_test_split(df[x_cols], df[y_cols], test_size=1-train_split, random_state=random_state, shuffle=True)
    X_val, X_test, y_val, y_test = train_test_split(X_tmp, y_tmp, test_size=test_split, random_state=random_state)

    return np.array([im for im in X_train.values]), np.array([im for im in y_train.values]), np.array([im for im in X_val.values]), np.array([im for im in y_val.values]), np.array([im for im in X_test.values]), np.array([im for im in y_test.values])

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_dataframe(d, x_cols='Images', y_cols='Labels', train_split=0.7, test_split=0.5, random_state=0)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1749, 224, 224, 3), (375, 224, 224, 3), (376, 224, 224, 3))

# %% [markdown]
# # Import du modèle d'apprentissage

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

vgg16_load = tf.keras.applications.VGG16(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=5,
    classifier_activation="softmax",
)

model = Sequential()
for layer in vgg16_load.layers[:-1]: # just exclude last layer from copying
    model.add(layer)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense (Dense)               (None, 1024)              4195328
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 138,719,557
# Trainable params: 138,719,557
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=1e-3), 
    loss= 'categorical_crossentropy',
    metrics= ['accuracy']
    )

# %%
epochs = 75
batch_size = 20
path = '/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/vgg_upgrade'
checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath=f'{path}/weights.bestaugmented.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    callbacks=[checkpointer], 
    verbose=1
    )
# Out:
# Epoch 1/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6199 - accuracy: 0.1887
# Epoch 1: val_loss improved from inf to 1.60933, saving model to /content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/vgg_upgrade/weights.bestaugmented.from_scratch.hdf5
# 87/87 [==============================] - 112s 1s/step - loss: 1.6199 - accuracy: 0.1887 - val_loss: 1.6093 - val_accuracy: 0.2027
# Epoch 2/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6101 - accuracy: 0.1816
# Epoch 2: val_loss improved from 1.60933 to 1.60930, saving model to /content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/vgg_upgrade/weights.bestaugmented.from_scratch.hdf5
# 87/87 [==============================] - 78s 892ms/step - loss: 1.6101 - accuracy: 0.1816 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 3/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6099 - accuracy: 0.1981
# Epoch 3: val_loss did not improve from 1.60930
# 87/87 [==============================] - 62s 713ms/step - loss: 1.6099 - accuracy: 0.1981 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 4/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6100 - accuracy: 0.2064
# Epoch 4: val_loss did not improve from 1.60930
# 87/87 [==============================] - 62s 711ms/step - loss: 1.6100 - accuracy: 0.2064 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 5/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6098 - accuracy: 0.1838
# Epoch 5: val_loss did not improve from 1.60930
# 87/87 [==============================] - 62s 712ms/step - loss: 1.6098 - accuracy: 0.1838 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 6/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6099 - accuracy: 0.1898
# Epoch 6: val_loss did not improve from 1.60930
# 87/87 [==============================] - 62s 710ms/step - loss: 1.6099 - accuracy: 0.1898 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 7/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6092 - accuracy: 0.2191
# Epoch 7: val_loss improved from 1.60930 to 1.60929, saving model to /content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/vgg_upgrade/weights.bestaugmented.from_scratch.hdf5
# 87/87 [==============================] - 77s 888ms/step - loss: 1.6092 - accuracy: 0.2191 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 8/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6098 - accuracy: 0.1948
# Epoch 8: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 711ms/step - loss: 1.6098 - accuracy: 0.1948 - val_loss: 1.6094 - val_accuracy: 0.1947
# Epoch 9/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.1937
# Epoch 9: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6097 - accuracy: 0.1937 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 10/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.1898
# Epoch 10: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6094 - accuracy: 0.1898 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 11/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6098 - accuracy: 0.1915
# Epoch 11: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6098 - accuracy: 0.1915 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 12/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.1882
# Epoch 12: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6094 - accuracy: 0.1882 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 13/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.1970
# Epoch 13: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6096 - accuracy: 0.1970 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 14/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6100 - accuracy: 0.2020
# Epoch 14: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6100 - accuracy: 0.2020 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 15/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.2047
# Epoch 15: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.2047 - val_loss: 1.6095 - val_accuracy: 0.2027
# Epoch 16/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.2042
# Epoch 16: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.2042 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 17/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.1954
# Epoch 17: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.1954 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 18/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.1926
# Epoch 18: val_loss did not improve from 1.60929
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6097 - accuracy: 0.1926 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 19/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.1981
# Epoch 19: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.1981 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 20/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.2036
# Epoch 20: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.2036 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 21/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.1998
# Epoch 21: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6094 - accuracy: 0.1998 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 22/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6099 - accuracy: 0.1860
# Epoch 22: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6099 - accuracy: 0.1860 - val_loss: 1.6095 - val_accuracy: 0.2080
# Epoch 23/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.2014
# Epoch 23: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6094 - accuracy: 0.2014 - val_loss: 1.6094 - val_accuracy: 0.1947
# Epoch 24/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.2020
# Epoch 24: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.2020 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 25/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.2025
# Epoch 25: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6097 - accuracy: 0.2025 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 26/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.1998
# Epoch 26: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6095 - accuracy: 0.1998 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 27/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.2086
# Epoch 27: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6095 - accuracy: 0.2086 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 28/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.1914
# Epoch 28: val_loss did not improve from 1.60929
# 87/87 [==============================] - 61s 704ms/step - loss: 1.6096 - accuracy: 0.1914 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 29/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.2020
# Epoch 29: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.2020 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 30/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.1904
# Epoch 30: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.1904 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 31/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.2053
# Epoch 31: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.2053 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 32/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.2003
# Epoch 32: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.2003 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 33/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.2092
# Epoch 33: val_loss improved from 1.60929 to 1.60929, saving model to /content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/vgg_upgrade/weights.bestaugmented.from_scratch.hdf5
# 87/87 [==============================] - 78s 898ms/step - loss: 1.6094 - accuracy: 0.2092 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 34/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.1921
# Epoch 34: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 710ms/step - loss: 1.6095 - accuracy: 0.1921 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 35/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.2097
# Epoch 35: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6095 - accuracy: 0.2097 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 36/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.1943
# Epoch 36: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.1943 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 37/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6090 - accuracy: 0.2130
# Epoch 37: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6090 - accuracy: 0.2130 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 38/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6101 - accuracy: 0.1854
# Epoch 38: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6101 - accuracy: 0.1854 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 39/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6093 - accuracy: 0.1992
# Epoch 39: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.1992 - val_loss: 1.6095 - val_accuracy: 0.1947
# Epoch 40/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6093 - accuracy: 0.1965
# Epoch 40: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.1965 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 41/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6098 - accuracy: 0.2009
# Epoch 41: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6098 - accuracy: 0.2009 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 42/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6093 - accuracy: 0.2053
# Epoch 42: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.2053 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 43/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6099 - accuracy: 0.2003
# Epoch 43: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6099 - accuracy: 0.2003 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 44/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6093 - accuracy: 0.1998
# Epoch 44: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.1998 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 45/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6093 - accuracy: 0.1959
# Epoch 45: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.1959 - val_loss: 1.6094 - val_accuracy: 0.1947
# Epoch 46/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.2014
# Epoch 46: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.2014 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 47/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.2025
# Epoch 47: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.2025 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 48/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6093 - accuracy: 0.2119
# Epoch 48: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.2119 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 49/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6099 - accuracy: 0.1854
# Epoch 49: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6099 - accuracy: 0.1854 - val_loss: 1.6095 - val_accuracy: 0.1947
# Epoch 50/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.1992
# Epoch 50: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.1992 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 51/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6093 - accuracy: 0.2042
# Epoch 51: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6093 - accuracy: 0.2042 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 52/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.2003
# Epoch 52: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6096 - accuracy: 0.2003 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 53/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.2025
# Epoch 53: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.2025 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 54/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.2014
# Epoch 54: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.2014 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 55/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.2025
# Epoch 55: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.2025 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 56/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.2053
# Epoch 56: val_loss did not improve from 1.60929
# 87/87 [==============================] - 61s 704ms/step - loss: 1.6094 - accuracy: 0.2053 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 57/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.2031
# Epoch 57: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.2031 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 58/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.2031
# Epoch 58: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.2031 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 59/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.2036
# Epoch 59: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.2036 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 60/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6093 - accuracy: 0.2064
# Epoch 60: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.2064 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 61/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.2042
# Epoch 61: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 712ms/step - loss: 1.6095 - accuracy: 0.2042 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 62/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6098 - accuracy: 0.1865
# Epoch 62: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6098 - accuracy: 0.1865 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 63/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.2081
# Epoch 63: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.2081 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 64/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.2020
# Epoch 64: val_loss did not improve from 1.60929
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6094 - accuracy: 0.2020 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 65/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.2141
# Epoch 65: val_loss improved from 1.60929 to 1.60928, saving model to /content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/vgg_upgrade/weights.bestaugmented.from_scratch.hdf5
# 87/87 [==============================] - 79s 909ms/step - loss: 1.6094 - accuracy: 0.2141 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 66/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.1965
# Epoch 66: val_loss did not improve from 1.60928
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6095 - accuracy: 0.1965 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 67/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.2053
# Epoch 67: val_loss improved from 1.60928 to 1.60925, saving model to /content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/vgg_upgrade/weights.bestaugmented.from_scratch.hdf5
# 87/87 [==============================] - 78s 902ms/step - loss: 1.6097 - accuracy: 0.2053 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 68/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.1976
# Epoch 68: val_loss did not improve from 1.60925
# 87/87 [==============================] - 62s 710ms/step - loss: 1.6096 - accuracy: 0.1976 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 69/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6092 - accuracy: 0.2081
# Epoch 69: val_loss did not improve from 1.60925
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6092 - accuracy: 0.2081 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 70/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.2075
# Epoch 70: val_loss did not improve from 1.60925
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.2075 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 71/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.1981
# Epoch 71: val_loss did not improve from 1.60925
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.1981 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 72/75
# 87/87 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.1965
# Epoch 72: val_loss did not improve from 1.60925
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.1965 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 73/75
# 36/87 [===========>..................] - ETA: 33s - loss: 1.6093 - accuracy: 0.2200WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6525 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 73: val_loss did not improve from 1.60925
# 87/87 [==============================] - 28s 321ms/step - loss: 1.6093 - accuracy: 0.2200 - val_loss: 1.6093 - val_accuracy: 0.2080

# %%
#model.load_weights(f'{path}/weights.bestaugmented.from_scratch.hdf5')

# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in X_test]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(y_test, axis=1))/len(dog_breed_predictions)
print(f'Test accuracy: {test_accuracy} %')
# Out:
# Test accuracy: 17.5531914893617 %

# %%
(eval_loss, eval_accuracy) = model.evaluate(X_test, y_test, batch_size= batch_size, verbose= 1)
print('Validation Loss: ', eval_loss)
print('Validation Accuracy: ', eval_accuracy)
# Out:
# 19/19 [==============================] - 8s 318ms/step - loss: 1.6107 - accuracy: 0.1755
# Validation Loss:  1.6106889247894287
# Validation Accuracy:  0.17553190886974335

# %%
plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()

# %%
model = Sequential()
for layer in vgg16_load.layers[:-1]: # just exclude last layer from copying
    model.add(layer)
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5, activation='softmax'))

display(model.summary())

model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=1e-3), 
    loss= 'categorical_crossentropy',
    metrics= ['accuracy']
    )

epochs = 75
batch_size = 20
path = '/content/drive/MyDrive/Colab Notebooks/OpenClassRooms/6/saved_model/vgg_upgrade'
checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath=f'{path}/weights.bestaugmented.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

history = model.fit(
    x=X_train, y=y_train,
    validation_data=(X_val, y_val), 
    steps_per_epoch=X_train.shape[0]//batch_size, 
    epochs=epochs, 
    #callbacks=[checkpointer], 
    verbose=1
    )



# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in X_test]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(y_test, axis=1))/len(dog_breed_predictions)
print(f'Test accuracy: {test_accuracy} %')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense_3 (Dense)             (None, 512)               2097664
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 136,490,821
# Trainable params: 136,490,821
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/75
# 87/87 [==============================] - 64s 713ms/step - loss: 1.6096 - accuracy: 0.1965 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 2/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6096 - accuracy: 0.1948 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 3/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.1915 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 4/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6096 - accuracy: 0.1954 - val_loss: 1.6094 - val_accuracy: 0.1947
# Epoch 5/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6094 - accuracy: 0.1860 - val_loss: 1.6094 - val_accuracy: 0.1947
# Epoch 6/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.1887 - val_loss: 1.6094 - val_accuracy: 0.1947
# Epoch 7/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.2003 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 8/75
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6095 - accuracy: 0.1948 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 9/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.2075 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 10/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.1943 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 11/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.2075 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 12/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.1932 - val_loss: 1.6094 - val_accuracy: 0.1947
# Epoch 13/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.1921 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 14/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6096 - accuracy: 0.2014 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 15/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6095 - accuracy: 0.2025 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 16/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6092 - accuracy: 0.2058 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 17/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.1987 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 18/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.2125 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 19/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.1882 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 20/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6090 - accuracy: 0.2158 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 21/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6098 - accuracy: 0.1987 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 22/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.1926 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 23/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.1898 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 24/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6095 - accuracy: 0.1909 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 25/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.1904 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 26/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.2031 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 27/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.2042 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 28/75
# 87/87 [==============================] - 61s 703ms/step - loss: 1.6095 - accuracy: 0.1931 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 29/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.2025 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 30/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.2064 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 31/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.2053 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 32/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.2009 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 33/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.1948 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 34/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.2064 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 35/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.1981 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 36/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.2014 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 37/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6096 - accuracy: 0.1948 - val_loss: 1.6093 - val_accuracy: 0.2027
# Epoch 38/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.1970 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 39/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6096 - accuracy: 0.1843 - val_loss: 1.6095 - val_accuracy: 0.1947
# Epoch 40/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6094 - accuracy: 0.2036 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 41/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6095 - accuracy: 0.1948 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 42/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.1943 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 43/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6096 - accuracy: 0.1954 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 44/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6098 - accuracy: 0.1970 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 45/75
# 87/87 [==============================] - 63s 728ms/step - loss: 1.6093 - accuracy: 0.2031 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 46/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6091 - accuracy: 0.2081 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 47/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6096 - accuracy: 0.2130 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 48/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6099 - accuracy: 0.1921 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 49/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6094 - accuracy: 0.2042 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 50/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6093 - accuracy: 0.2119 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 51/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6095 - accuracy: 0.1854 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 52/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6097 - accuracy: 0.1970 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 53/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6096 - accuracy: 0.2003 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 54/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6094 - accuracy: 0.2086 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 55/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6095 - accuracy: 0.2031 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 56/75
# 87/87 [==============================] - 61s 702ms/step - loss: 1.6095 - accuracy: 0.2031 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 57/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6094 - accuracy: 0.2036 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 58/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6096 - accuracy: 0.2014 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 59/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6094 - accuracy: 0.2081 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 60/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6097 - accuracy: 0.2003 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 61/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6093 - accuracy: 0.2053 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 62/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6096 - accuracy: 0.2031 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 63/75
# 87/87 [==============================] - 61s 707ms/step - loss: 1.6097 - accuracy: 0.2003 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 64/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6093 - accuracy: 0.2025 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 65/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6092 - accuracy: 0.2136 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 66/75
# 87/87 [==============================] - 62s 708ms/step - loss: 1.6097 - accuracy: 0.1948 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 67/75
# 87/87 [==============================] - 62s 707ms/step - loss: 1.6094 - accuracy: 0.2070 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 68/75
# 87/87 [==============================] - 62s 710ms/step - loss: 1.6092 - accuracy: 0.1959 - val_loss: 1.6094 - val_accuracy: 0.2027
# Epoch 69/75
# 87/87 [==============================] - 62s 711ms/step - loss: 1.6097 - accuracy: 0.1998 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 70/75
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6096 - accuracy: 0.1981 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 71/75
# 87/87 [==============================] - 62s 710ms/step - loss: 1.6096 - accuracy: 0.2020 - val_loss: 1.6093 - val_accuracy: 0.2080
# Epoch 72/75
# 87/87 [==============================] - 62s 709ms/step - loss: 1.6090 - accuracy: 0.1987 - val_loss: 1.6094 - val_accuracy: 0.2080
# Epoch 73/75
# 36/87 [===========>..................] - ETA: 33s - loss: 1.6101 - accuracy: 0.1997WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6525 batches). You may need to use the repeat() function when building your dataset.
# 87/87 [==============================] - 27s 309ms/step - loss: 1.6101 - accuracy: 0.1997 - val_loss: 1.6094 - val_accuracy: 0.2080
# Test accuracy: 17.5531914893617 %

# %%
plt.subplot()
plt.title('Model Accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

plt.title('Model Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss','Validation Loss'])
plt.show()
